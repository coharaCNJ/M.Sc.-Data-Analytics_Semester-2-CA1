# %% [markdown]
# # Another attempt at using PySpark

# %%
#Spark UI
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
# sc master - running locally
sc.master
# Out:
# 'local[*]'

# %%
import os
from tqdm import tqdm
import PIL.Image
import numpy as np #For numerical functions, incl. statistical.
import matplotlib.pyplot as plt #2D plotting libraryS
import cv2
import pandas as pd
from tensorflow.keras import Sequential
#from keras.utils import np_utils
from keras import utils
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
import tensorflow as tf
from tabulate import tabulate
#from sklearn.model_selection import GridSearchCV
#from keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# ## The below will not work, I cannot import any mllearn algorithms, and have not been able to find any way to resolve after much searching
#
# #### Had been hoping to utilise distributed learning using a Keras2DML wrapper following a tutorial similar to the below, but could not progress with this.
#
# https://towardsdatascience.com/how-to-train-your-neural-networks-in-parallel-with-keras-and-apache-spark-ea8a3f48cae6
#
# Instead, in order to ensure that the CNN model could run, the image sizes were reduced.

# %%
from systemml.mllearn import Keras2DML
# Out:
# Traceback (most recent call last):
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipykernel_18018/3750211843.py", line 1, in <module>
#     from systemml.mllearn import Keras2DML
#
#   File "/home/hduser/.local/lib/python3.10/site-packages/systemml/mllearn/__init__.py", line 45, in <module>
#     from .estimators import *
#
#   File "/home/hduser/.local/lib/python3.10/site-packages/systemml/mllearn/estimators.py", line 939
#     from .keras2caffe import *
#                              ^
# SyntaxError: import * only allowed at module level

# %% [markdown]
# # Deep learning without distributed systems

# %%
#Functions to create labelled data
def assign_label(img,group):
    return group

X = []
y = []

def make_data(group,directory):
    print(group)
    print(directory)
    for img in tqdm(os.listdir(directory)):
        label=assign_label(img,group)
        path = os.path.join(directory,img)
        img = PIL.Image.open(path)
        
        X.append(np.array(img))
        y.append(str(label))

# %% [markdown]
# ## Classifying between Mayfly genera

# %%
mayfly_groups = {'Ecdyonurus':0,'Seratella':1,'Baetis':2}

# %%
Ecdyonurus_directory = os.getcwd() + '/Species_images/Mayflies_Ephemeroptera/'
Seratella_directory = os.getcwd() + '/Species_images/mayflies/Baetis_mayfly'
Baetis_directory = os.getcwd() + '/Species_images/mayflies/Seratella_mayflies'

# %%
make_data(mayfly_groups.get('Ecdyonurus'), Ecdyonurus_directory)
make_data(mayfly_groups.get('Seratella'), Seratella_directory)
make_data(mayfly_groups.get('Baetis'), Baetis_directory)
# Out:
# 0
# /home/hduser/Dropbox/M.Sc. Data Analytics/CAs/CA3/Git_submission_folder/Species_images/Mayflies_Ephemeroptera/
# 100%|█████████████████████████████████████████| 10/10 [00:00<00:00, 2331.08it/s]
# 1
# /home/hduser/Dropbox/M.Sc. Data Analytics/CAs/CA3/Git_submission_folder/Species_images/Baetis_mayfly
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 194.03it/s]
# 2
# /home/hduser/Dropbox/M.Sc. Data Analytics/CAs/CA3/Git_submission_folder/Species_images/Seratella_mayflies
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 205.90it/s]

# %%
X = np.array(X)
X /= 255
X.shape
# Out:
# /tmp/ipykernel_16829/2660155455.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array(X)
# (30,)

# %%
min_width = 0
min_height = 0

for x in range(len(X)):
    min_width = X[x].shape[1]
    min_height = X[x].shape[0]
    if X[x].shape[1] < min_width:
        min_width = X[x].shape[1]
    if X[x].shape[0] < min_height:
        min_height = X[x].shape[0]

# %%
#resize the images to feed the model
#The images had to be made 250 x 250 to ensure that the CNN model could build and run
for x in range(len(X)):
    X[x] = cv2.resize(X[x], (min(min_width, 250), min(min_height, 250)))

# %%
plt.imshow(X[3])

# %%
plt.imshow(X[15])

# %%
plt.imshow(X[29])

# %%
images = []
for x in range(len(X)):
    images.append(X[x])

# %%
images = np.array(images)

# %%
images.shape
# Out:
# (30, 250, 250, 3)

# %%
images[4].shape, images[7].shape
# Out:
# ((250, 250, 3), (250, 250, 3))

# %%
images = images.astype('float32')

# %%
#Convert the list to an array:
y = np.array(y)

#The number of species = 3. One hot encode these:
n_classes = 3
print("Shape before one-hot encoding: ", y.shape)
y = utils.to_categorical(y, n_classes)
#y = np_utils.to_categorical(y, n_classes)
print("Shape after one-hot encoding: ", y.shape)
# Out:
# Shape before one-hot encoding:  (30,)
# Shape after one-hot encoding:  (30, 3)

# %%
images = tf.convert_to_tensor(images)
# Out:
# 2023-09-22 14:47:15.139639: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-22 14:47:15.141405: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-09-22 14:47:15.146065: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 22500000 exceeds 10% of free system memory.

# %%
#Defining the model
model = Sequential()
model.add(Conv2D(25, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu',input_shape=(X[0].shape[0],X[0].shape[1],3)))
model.add(MaxPool2D(pool_size=(1,1))) #A filter that takes the max pixel value that falls within it
# flatten output of conv
model.add(Flatten())
# hidden layer
model.add(Dense(100, activation='relu')) #One layer neural network
# output layer (3 nodes because there are 3 classes)
model.add(Dense(3, activation='softmax')) #Softmax because it is a classification problem
# Out:
# 2023-09-22 14:47:16.028726: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 615040000 exceeds 10% of free system memory.
# 2023-09-22 14:47:16.385241: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 615040000 exceeds 10% of free system memory.
# 2023-09-22 14:47:16.744147: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 615040000 exceeds 10% of free system memory.

# %%
# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 248, 248, 25)      700
#
#  max_pooling2d (MaxPooling2  (None, 248, 248, 25)      0
#  D)
#
#  flatten (Flatten)           (None, 1537600)           0
#
#  dense (Dense)               (None, 100)               153760100
#
#  dense_1 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 153761103 (586.55 MB)
# Trainable params: 153761103 (586.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# This had to be abandoned, as above because KERAS2DML could not be imported, with no solution apparent.
epochs = 5
batch_size = 10
samples = 30

# %%
# training the model

#low batch size because there are so few images
model.fit(images, y, batch_size=5, epochs=10, validation_data=(images, y))
# Out:
# Epoch 1/10
# 2023-09-19 19:41:41.261239: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 615040000 exceeds 10% of free system memory.
# 2023-09-19 19:41:41.364453: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 615040000 exceeds 10% of free system memory.
# 6/6 [==============================] - 14s 2s/step - loss: 215.0398 - accuracy: 0.3000 - val_loss: 27.4990 - val_accuracy: 0.3667
# Epoch 2/10
# 6/6 [==============================] - 13s 2s/step - loss: 29.6592 - accuracy: 0.3667 - val_loss: 1.5814 - val_accuracy: 0.4333
# Epoch 3/10
# 6/6 [==============================] - 13s 2s/step - loss: 9.6542 - accuracy: 0.3333 - val_loss: 10.1789 - val_accuracy: 0.4000
# Epoch 4/10
# 6/6 [==============================] - 13s 2s/step - loss: 5.4286 - accuracy: 0.3667 - val_loss: 3.1661 - val_accuracy: 0.3333
# Epoch 5/10
# 6/6 [==============================] - 13s 2s/step - loss: 1.7734 - accuracy: 0.5333 - val_loss: 0.6025 - val_accuracy: 0.7000
# Epoch 6/10
# 6/6 [==============================] - 13s 2s/step - loss: 0.3277 - accuracy: 0.8667 - val_loss: 0.1514 - val_accuracy: 1.0000
# Epoch 7/10
# 6/6 [==============================] - 13s 2s/step - loss: 0.1413 - accuracy: 1.0000 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 8/10
# 6/6 [==============================] - 13s 2s/step - loss: 0.0614 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 1.0000
# Epoch 9/10
# 6/6 [==============================] - 13s 2s/step - loss: 0.0648 - accuracy: 0.9667 - val_loss: 0.0286 - val_accuracy: 1.0000
# Epoch 10/10
# 6/6 [==============================] - 13s 2s/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 1.0000

# %% [markdown]
# |  Batch size  |  Epochs  |   Filters   |  Kernel size  |  Accuracy achieved  |  Loss  |
# |--------------|----------|-------------|---------------|---------------------|--------|
# |      3       |    10    |     10      |     3 x 3     |         77%         |  1.100 |
# |      10      |    10    |     25      |     3 x 3     |         50%         |  0.071 |
# |      3       |    10    |     25      |     3 x 3     |        100%         | 11.990 |
# |      5       |    10    |     25      |     3 x 3     |        100%         |  0.036 |

# %% [markdown]
# # Train a VGG-16 model

# %%
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from keras.optimizers import Adam

import tensorflow as tf
import keras, os
from tensorflow.keras import Sequential
from tensorflow.keras import utils
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import matplotlib.pyplot as plt
# Out:
# 2023-09-23 13:02:04.381882: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-09-23 13:02:04.381898: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
mayflies = os.getcwd() + '/Species_images/mayflies/'

# %%
trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory=mayflies,target_size=(250,250))
# Out:
# Found 30 images belonging to 3 classes.

# %%
#VGG-16 model is giving poor results, viewing images to ensure that they imported images are OK

images, _ = next(traindata)
plt.imshow(images[5].astype('uint8'))

# %%
#Ensure that shape matches what is expected by the model
images[5].shape
# Out:
# (250, 250, 3)

# %% [markdown]
# ### Generate a VGG-16 model from scratch (after https://builtin.com/machine-learning/vgg16)

# %%
#Build the model

model = Sequential()
model.add(Conv2D(input_shape=(250,250,3),filters=20,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=3, activation="softmax")) #3 species
# Out:
# 2023-09-23 13:02:16.763369: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-09-23 13:02:16.787929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-23 13:02:16.788183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:29:00.0 name: NVIDIA GeForce GTX 1660 Ti computeCapability: 7.5
# coreClock: 1.875GHz coreCount: 24 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 268.26GiB/s
# 2023-09-23 13:02:16.788317: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-09-23 13:02:16.788605: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-09-23 13:02:16.788883: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-09-23 13:02:16.789141: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-09-23 13:02:16.789263: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2023-09-23 13:02:16.789377: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2023-09-23 13:02:16.789764: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-09-23 13:02:16.789883: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-09-23 13:02:16.789897: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-09-23 13:02:16.790335: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-23 13:02:16.790972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-09-23 13:02:16.790987: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]

# %%
#Compile the model

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 250, 250, 20)      560
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 250, 250, 64)      11584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 125, 125, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 125, 125, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 62, 62, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 62, 62, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 62, 62, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 31, 31, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 31, 31, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 31, 31, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 31, 31, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 15, 15, 512)       2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 15, 512)       2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 15, 15, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12291
# =================================================================
# Total params: 134,246,259
# Trainable params: 134,246,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fit the model
model.fit(traindata, batch_size = 5, epochs=10, validation_data=traindata)
# Out:
# 2023-09-23 13:02:23.807883: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-09-23 13:02:23.808296: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3599530000 Hz
# Epoch 1/10
# 1/1 [==============================] - 21s 21s/step - loss: 1.2364 - accuracy: 0.3333 - val_loss: 6558.8794 - val_accuracy: 0.3333
# Epoch 2/10
# 1/1 [==============================] - 20s 20s/step - loss: 6558.8794 - accuracy: 0.3333 - val_loss: 4.3880 - val_accuracy: 0.3333
# Epoch 3/10
# 1/1 [==============================] - 20s 20s/step - loss: 4.3880 - accuracy: 0.3333 - val_loss: 1.5004 - val_accuracy: 0.3333
# Epoch 4/10
# 1/1 [==============================] - 20s 20s/step - loss: 1.5004 - accuracy: 0.3333 - val_loss: 1.3208 - val_accuracy: 0.3333
# Epoch 5/10
# 1/1 [==============================] - 20s 20s/step - loss: 1.3208 - accuracy: 0.3333 - val_loss: 1.2102 - val_accuracy: 0.3333
# Epoch 6/10
# 1/1 [==============================] - 20s 20s/step - loss: 1.2102 - accuracy: 0.3333 - val_loss: 1.1125 - val_accuracy: 0.3333
# Epoch 7/10
# 1/1 [==============================] - 20s 20s/step - loss: 1.1125 - accuracy: 0.3333 - val_loss: 1.1064 - val_accuracy: 0.3333
# Epoch 8/10
# 1/1 [==============================] - 20s 20s/step - loss: 1.1064 - accuracy: 0.3333 - val_loss: 1.0989 - val_accuracy: 0.3333
# Epoch 9/10
# 1/1 [==============================] - 20s 20s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0988 - val_accuracy: 0.3333
# Epoch 10/10
# 1/1 [==============================] - 20s 20s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0983 - val_accuracy: 0.3333

# %% [markdown]
# #### Epochs = 10 throughout
# #### Initial filter is initail Conv2D filter
#
# |  Batch size  |  Initial filter  |  Kernel size  |  Accuracy achieved  |  Loss  |
# |--------------|------------------|---------------|---------------------|--------|
# |      na      |         64       |     3 x 3     |         33%         |  1.110 |
# |      5       |         64       |     3 x 3     |         33%         |  1.240 |
# |      5       |         20       |     3 x 3     |         33%         | 11.990 |
